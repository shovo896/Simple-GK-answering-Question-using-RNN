# %%
import pandas as pd

# %%
df=pd.read_csv("gk_qna_dataset.csv")
df.head(5)
# Out:
#                             question  answer
# 0   What is the capital of "France"?   Paris
# 1  What is the capital of "Germany"?  Berlin
# 2    What is the capital of "Italy"?    Rome
# 3    What is the capital of "Spain"?  Madrid
# 4    What is the capital of "Japan"?   Tokyo

# %%
df['question'][0]
# Out:
# 'What is the capital of "France"?'

# %% [markdown]
# tokenization

# %%
import re 

def tokenize(text):
       #lowercase 
       text=text.lower()


       # remove quotes 
       text=re.sub(r"[\'\"]", "", text)


       # remove all punctuations 
       text=re.sub(r"[^a-z0-9\s]", "", text)
       text=re.sub(r"\s+", " ", text)

       #remove extra space
       tokens=text.split()


       return tokens

# %%
print(tokenize(df['question'][0]))
# Out:
# ['what', 'is', 'the', 'capital', 'of', 'france']

# %%
vocab={'UNK': 0}

# %%
def build_vocab(row):
       print(row['question'],row['answer'])

       tokenized_question = tokenize(row['question'])
       tokenized_answer = tokenize(row['answer'])
       print(tokenized_question,tokenized_answer)
       merged_tokens=tokenized_question+tokenized_answer
       for token in merged_tokens:
              if token not in vocab:
                     vocab[token]=len(vocab)

# %%
df.apply(build_vocab,axis=1)
# Out:
# What is the capital of "France"? Paris
# ['what', 'is', 'the', 'capital', 'of', 'france'] ['paris']
# What is the capital of "Germany"? Berlin
# ['what', 'is', 'the', 'capital', 'of', 'germany'] ['berlin']
# What is the capital of "Italy"? Rome
# ['what', 'is', 'the', 'capital', 'of', 'italy'] ['rome']
# What is the capital of "Spain"? Madrid
# ['what', 'is', 'the', 'capital', 'of', 'spain'] ['madrid']
# What is the capital of "Japan"? Tokyo
# ['what', 'is', 'the', 'capital', 'of', 'japan'] ['tokyo']
# What is the capital of "Canada"? Ottawa
# ['what', 'is', 'the', 'capital', 'of', 'canada'] ['ottawa']
# What is the capital of "Brazil"? Brasilia
# ['what', 'is', 'the', 'capital', 'of', 'brazil'] ['brasilia']
# What is the capital of "Australia"? Canberra
# ['what', 'is', 'the', 'capital', 'of', 'australia'] ['canberra']
# What is the capital of "India"? New Delhi
# ['what', 'is', 'the', 'capital', 'of', 'india'] ['new', 'delhi']
# What is the capital of "China"? Beijing
# ['what', 'is', 'the', 'capital', 'of', 'china'] ['beijing']
# What is the capital of "Russia"? Moscow
# ['what', 'is', 'the', 'capital', 'of', 'russia'] ['moscow']
# What is the capital of "United States"? Washington DC
# ['what', 'is', 'the', 'capital', 'of', 'united', 'states'] ['washington', 'dc']
# What is the capital of "Mexico"? Mexico City
# ['what', 'is', 'the', 'capital', 'of', 'mexico'] ['mexico', 'city']
# What is the capital of "Egypt"? Cairo
# ['what', 'is', 'the', 'capital', 'of', 'egypt'] ['cairo']
# What is the capital of "Turkey"? Ankara
# ['what', 'is', 'the', 'capital', 'of', 'turkey'] ['ankara']
# What is the capital of "Argentina"? Buenos Aires
# ['what', 'is', 'the', 'capital', 'of', 'argentina'] ['buenos', 'aires']
# What is the capital of "South Korea"? Seoul
# ['what', 'is', 'the', 'capital', 'of', 'south', 'korea'] ['seoul']
# What is the capital of "Indonesia"? Jakarta
# ['what', 'is', 'the', 'capital', 'of', 'indonesia'] ['jakarta']
# What is the capital of "Pakistan"? Islamabad
# ['what', 'is', 'the', 'capital', 'of', 'pakistan'] ['islamabad']
# What is the capital of "Bangladesh"? Dhaka
# ['what', 'is', 'the', 'capital', 'of', 'bangladesh'] ['dhaka']
# What is the capital of "Nepal"? Kathmandu
# ['what', 'is', 'the', 'capital', 'of', 'nepal'] ['kathmandu']
# What is the capital of "Sri Lanka"? Colombo
# ['what', 'is', 'the', 'capital', 'of', 'sri', 'lanka'] ['colombo']
# What is the capital of "Thailand"? Bangkok
# ['what', 'is', 'the', 'capital', 'of', 'thailand'] ['bangkok']
# What is the capital of "Malaysia"? Kuala Lumpur
# ['what', 'is', 'the', 'capital', 'of', 'malaysia'] ['kuala', 'lumpur']
# What is the capital of "Vietnam"? Hanoi
# ['what', 'is', 'the', 'capital', 'of', 'vietnam'] ['hanoi']
# What is the capital of "UAE"? Abu Dhabi
# ['what', 'is', 'the', 'capital', 'of', 'uae'] ['abu', 'dhabi']
# What is the capital of "Iran"? Tehran
# ['what', 'is', 'the', 'capital', 'of', 'iran'] ['tehran']
# What is the capital of "Iraq"? Baghdad
# ['what', 'is', 'the', 'capital', 'of', 'iraq'] ['baghdad']
# What is the capital of "Saudi Arabia"? Riyadh
# ['what', 'is', 'the', 'capital', 'of', 'saudi', 'arabia'] ['riyadh']
# What is the capital of "Nigeria"? Abuja
# ['what', 'is', 'the', 'capital', 'of', 'nigeria'] ['abuja']
# What is the capital of "Kenya"? Nairobi
# ['what', 'is', 'the', 'capital', 'of', 'kenya'] ['nairobi']
# What is the capital of "Chile"? Santiago
# ['what', 'is', 'the', 'capital', 'of', 'chile'] ['santiago']
# Who discovered 'gravity'? Isaac Newton
# ['who', 'discovered', 'gravity'] ['isaac', 'newton']
# Who invented the 'telephone'? Alexander Graham Bell
# ['who', 'invented', 'the', 'telephone'] ['alexander', 'graham', 'bell']
# What is 'H2O' commonly called? Water
# ['what', 'is', 'h2o', 'commonly', 'called'] ['water']
# Which gas do plants absorb? Carbon dioxide
# ['which', 'gas', 'do', 'plants', 'absorb'] ['carbon', 'dioxide']
# Which planet is known as the 'Red Planet'? Mars
# ['which', 'planet', 'is', 'known', 'as', 'the', 'red', 'planet'] ['mars']
# Who painted the 'Mona Lisa'? Leonardo da Vinci
# ['who', 'painted', 'the', 'mona', 'lisa'] ['leonardo', 'da', 'vinci']
# What is the largest ocean? Pacific Ocean
# ['what', 'is', 'the', 'largest', 'ocean'] ['pacific', 'ocean']
# Who developed the 'theory of relativity'? Albert Einstein
# ['who', 'developed', 'the', 'theory', 'of', 'relativity'] ['albert', 'einstein']
# What is 'AI' short for? Artificial Intelligence
# ['what', 'is', 'ai', 'short', 'for'] ['artificial', 'intelligence']
# What is 'ML' short for? Machine Learning
# ['what', 'is', 'ml', 'short', 'for'] ['machine', 'learning']
# What is 'NLP' short for? Natural Language Processing
# ['what', 'is', 'nlp', 'short', 'for'] ['natural', 'language', 'processing']
# What does 'CPU' stand for? Central Processing Unit
# ['what', 'does', 'cpu', 'stand', 'for'] ['central', 'processing', 'unit']
# What is 'RAM'? Computer memory
# ['what', 'is', 'ram'] ['computer', 'memory']
# What does 'GPU' stand for? Graphics Processing Unit
# ['what', 'does', 'gpu', 'stand', 'for'] ['graphics', 'processing', 'unit']
# What is a 'URL'? Web address
# ['what', 'is', 'a', 'url'] ['web', 'address']
# What does 'HTTP' stand for? HyperText Transfer Protocol
# ['what', 'does', 'http', 'stand', 'for'] ['hypertext', 'transfer', 'protocol']
# What is 'JSON' used for? Data exchange
# ['what', 'is', 'json', 'used', 'for'] ['data', 'exchange']
# What is 'SQL'? Database query language
# ['what', 'is', 'sql'] ['database', 'query', 'language']
# What does 'API' mean? Application Programming Interface
# ['what', 'does', 'api', 'mean'] ['application', 'programming', 'interface']
# Who invented the 'light bulb'? Thomas Edison
# ['who', 'invented', 'the', 'light', 'bulb'] ['thomas', 'edison']
# Who invented the 'airplane'? Wright Brothers
# ['who', 'invented', 'the', 'airplane'] ['wright', 'brothers']
# Who discovered 'penicillin'? Alexander Fleming
# ['who', 'discovered', 'penicillin'] ['alexander', 'fleming']
# Who wrote 'Hamlet'? William Shakespeare
# ['who', 'wrote', 'hamlet'] ['william', 'shakespeare']
# Who wrote 'Harry Potter'? J K Rowling
# ['who', 'wrote', 'harry', 'potter'] ['j', 'k', 'rowling']
# Which country is known as the 'Land of Rising Sun'? Japan
# ['which', 'country', 'is', 'known', 'as', 'the', 'land', 'of', 'rising', 'sun'] ['japan']
# Which animal is called the 'King of Jungle'? Lion
# ['which', 'animal', 'is', 'called', 'the', 'king', 'of', 'jungle'] ['lion']
# Which animal is the largest on Earth? Blue Whale
# ['which', 'animal', 'is', 'the', 'largest', 'on', 'earth'] ['blue', 'whale']
# Which bird cannot fly? Ostrich
# ['which', 'bird', 'cannot', 'fly'] ['ostrich']
# Which animal is known for loyalty? Dog
# ['which', 'animal', 'is', 'known', 'for', 'loyalty'] ['dog']
# Which fruit is typically red? Apple
# ['which', 'fruit', 'is', 'typically', 'red'] ['apple']
# Which fruit is yellow? Banana
# ['which', 'fruit', 'is', 'yellow'] ['banana']
# Which organ pumps blood? Heart
# ['which', 'organ', 'pumps', 'blood'] ['heart']
# Which gas do humans breathe? Oxygen
# ['which', 'gas', 'do', 'humans', 'breathe'] ['oxygen']
# Which metal is liquid at room temperature? Mercury
# ['which', 'metal', 'is', 'liquid', 'at', 'room', 'temperature'] ['mercury']
# Which instrument measures temperature? Thermometer
# ['which', 'instrument', 'measures', 'temperature'] ['thermometer']
# Which instrument measures pressure? Barometer
# ['which', 'instrument', 'measures', 'pressure'] ['barometer']
# What is the main language of Brazil? Portuguese
# ['what', 'is', 'the', 'main', 'language', 'of', 'brazil'] ['portuguese']
# What is the main language of Spain? Spanish
# ['what', 'is', 'the', 'main', 'language', 'of', 'spain'] ['spanish']
# What is the main religion in Saudi Arabia? Islam
# ['what', 'is', 'the', 'main', 'religion', 'in', 'saudi', 'arabia'] ['islam']
# What is the national animal of Bangladesh? Royal Bengal Tiger
# ['what', 'is', 'the', 'national', 'animal', 'of', 'bangladesh'] ['royal', 'bengal', 'tiger']
# Quick question: "Who invented the 'light bulb'"? Thomas Edison
# ['quick', 'question', 'who', 'invented', 'the', 'light', 'bulb'] ['thomas', 'edison']
# "Who discovered 'penicillin'" — do you know? Alexander Fleming
# ['who', 'discovered', 'penicillin', 'do', 'you', 'know'] ['alexander', 'fleming']
# Do you know, "What is the largest ocean"? Pacific Ocean
# ['do', 'you', 'know', 'what', 'is', 'the', 'largest', 'ocean'] ['pacific', 'ocean']
# I was wondering, "What is a 'URL'"? Web address
# ['i', 'was', 'wondering', 'what', 'is', 'a', 'url'] ['web', 'address']
# Hey, what about this: "Which instrument measures pressure"? Barometer
# ['hey', 'what', 'about', 'this', 'which', 'instrument', 'measures', 'pressure'] ['barometer']
# "Who invented the 'telephone'" — do you know? Alexander Graham Bell
# ['who', 'invented', 'the', 'telephone', 'do', 'you', 'know'] ['alexander', 'graham', 'bell']
# I was wondering, "Who invented the 'light bulb'"? Thomas Edison
# ['i', 'was', 'wondering', 'who', 'invented', 'the', 'light', 'bulb'] ['thomas', 'edison']
# Quick question: "What is the main language of Spain"? Spanish
# ['quick', 'question', 'what', 'is', 'the', 'main', 'language', 'of', 'spain'] ['spanish']
# Hey, what about this: "What is a 'URL'"? Web address
# ['hey', 'what', 'about', 'this', 'what', 'is', 'a', 'url'] ['web', 'address']
# I was wondering, "Which gas do humans breathe"? Oxygen
# ['i', 'was', 'wondering', 'which', 'gas', 'do', 'humans', 'breathe'] ['oxygen']
# I was wondering, "Which organ pumps blood"? Heart
# ['i', 'was', 'wondering', 'which', 'organ', 'pumps', 'blood'] ['heart']
# Hey, what about this: "What is the largest ocean"? Pacific Ocean
# ['hey', 'what', 'about', 'this', 'what', 'is', 'the', 'largest', 'ocean'] ['pacific', 'ocean']
# Do you know, "Who invented the 'telephone'"? Alexander Graham Bell
# ['do', 'you', 'know', 'who', 'invented', 'the', 'telephone'] ['alexander', 'graham', 'bell']
# Quick question: "Who wrote 'Hamlet'"? William Shakespeare
# ['quick', 'question', 'who', 'wrote', 'hamlet'] ['william', 'shakespeare']
# "Which instrument measures pressure" — do you know? Barometer
# ['which', 'instrument', 'measures', 'pressure', 'do', 'you', 'know'] ['barometer']
# Can you tell me, "What is the national animal of Bangladesh"? Royal Bengal Tiger
# ['can', 'you', 'tell', 'me', 'what', 'is', 'the', 'national', 'animal', 'of', 'bangladesh'] ['royal', 'bengal', 'tiger']
# Quick question: "What is the main language of Brazil"? Portuguese
# ['quick', 'question', 'what', 'is', 'the', 'main', 'language', 'of', 'brazil'] ['portuguese']
# Hey, what about this: "Who developed the 'theory of relativity'"? Albert Einstein
# ['hey', 'what', 'about', 'this', 'who', 'developed', 'the', 'theory', 'of', 'relativity'] ['albert', 'einstein']
# Hey, what about this: "What is 'AI' short for"? Artificial Intelligence
# ['hey', 'what', 'about', 'this', 'what', 'is', 'ai', 'short', 'for'] ['artificial', 'intelligence']
# I was wondering, "Which animal is known for loyalty"? Dog
# ['i', 'was', 'wondering', 'which', 'animal', 'is', 'known', 'for', 'loyalty'] ['dog']
# Do you know, "What is a 'URL'"? Web address
# ['do', 'you', 'know', 'what', 'is', 'a', 'url'] ['web', 'address']
# Quick question: "Which gas do plants absorb"? Carbon dioxide
# ['quick', 'question', 'which', 'gas', 'do', 'plants', 'absorb'] ['carbon', 'dioxide']
# I was wondering, "Who invented the 'telephone'"? Alexander Graham Bell
# ['i', 'was', 'wondering', 'who', 'invented', 'the', 'telephone'] ['alexander', 'graham', 'bell']
# Do you know, "Which fruit is yellow"? Banana
# ['do', 'you', 'know', 'which', 'fruit', 'is', 'yellow'] ['banana']
# Can you tell me, "Which planet is known as the 'Red Planet'"? Mars
# ['can', 'you', 'tell', 'me', 'which', 'planet', 'is', 'known', 'as', 'the', 'red', 'planet'] ['mars']
# Do you know, "Which gas do plants absorb"? Carbon dioxide
# ['do', 'you', 'know', 'which', 'gas', 'do', 'plants', 'absorb'] ['carbon', 'dioxide']
# Can you tell me, "What does 'CPU' stand for"? Central Processing Unit
# ['can', 'you', 'tell', 'me', 'what', 'does', 'cpu', 'stand', 'for'] ['central', 'processing', 'unit']
# Hey, what about this: "Who wrote 'Harry Potter'"? J K Rowling
# ['hey', 'what', 'about', 'this', 'who', 'wrote', 'harry', 'potter'] ['j', 'k', 'rowling']
# Do you know, "What does 'GPU' stand for"? Graphics Processing Unit
# ['do', 'you', 'know', 'what', 'does', 'gpu', 'stand', 'for'] ['graphics', 'processing', 'unit']
# Quick question: "Which gas do humans breathe"? Oxygen
# ['quick', 'question', 'which', 'gas', 'do', 'humans', 'breathe'] ['oxygen']
# I was wondering, "What is 'RAM'"? Computer memory
# ['i', 'was', 'wondering', 'what', 'is', 'ram'] ['computer', 'memory']
# Can you tell me, "What is the largest ocean"? Pacific Ocean
# ['can', 'you', 'tell', 'me', 'what', 'is', 'the', 'largest', 'ocean'] ['pacific', 'ocean']
# Quick question: "Which metal is liquid at room temperature"? Mercury
# ['quick', 'question', 'which', 'metal', 'is', 'liquid', 'at', 'room', 'temperature'] ['mercury']
# Quick question: "What is 'ML' short for"? Machine Learning
# ['quick', 'question', 'what', 'is', 'ml', 'short', 'for'] ['machine', 'learning']
# Hey, what about this: "Which fruit is yellow"? Banana
# ['hey', 'what', 'about', 'this', 'which', 'fruit', 'is', 'yellow'] ['banana']
# Hey, what about this: "Which instrument measures temperature"? Thermometer
# ['hey', 'what', 'about', 'this', 'which', 'instrument', 'measures', 'temperature'] ['thermometer']
# "Which animal is the largest on Earth" — do you know? Blue Whale
# ['which', 'animal', 'is', 'the', 'largest', 'on', 'earth', 'do', 'you', 'know'] ['blue', 'whale']
# "What is the largest ocean" — do you know? Pacific Ocean
# ['what', 'is', 'the', 'largest', 'ocean', 'do', 'you', 'know'] ['pacific', 'ocean']
# "Which organ pumps blood" — do you know? Heart
# ['which', 'organ', 'pumps', 'blood', 'do', 'you', 'know'] ['heart']
# Can you tell me, "Who wrote 'Hamlet'"? William Shakespeare
# ['can', 'you', 'tell', 'me', 'who', 'wrote', 'hamlet'] ['william', 'shakespeare']
# Do you know, "What is the main language of Brazil"? Portuguese
# ['do', 'you', 'know', 'what', 'is', 'the', 'main', 'language', 'of', 'brazil'] ['portuguese']
# "Who painted the 'Mona Lisa'" — do you know? Leonardo da Vinci
# ['who', 'painted', 'the', 'mona', 'lisa', 'do', 'you', 'know'] ['leonardo', 'da', 'vinci']
# Do you know, "Which country is known as the 'Land of Rising Sun'"? Japan
# ['do', 'you', 'know', 'which', 'country', 'is', 'known', 'as', 'the', 'land', 'of', 'rising', 'sun'] ['japan']
# Quick question: "Which animal is called the 'King of Jungle'"? Lion
# ['quick', 'question', 'which', 'animal', 'is', 'called', 'the', 'king', 'of', 'jungle'] ['lion']
# Can you tell me, "Which fruit is yellow"? Banana
# ['can', 'you', 'tell', 'me', 'which', 'fruit', 'is', 'yellow'] ['banana']
# Can you tell me, "Who invented the 'light bulb'"? Thomas Edison
# ['can', 'you', 'tell', 'me', 'who', 'invented', 'the', 'light', 'bulb'] ['thomas', 'edison']
# Quick question: "Who discovered 'penicillin'"? Alexander Fleming
# ['quick', 'question', 'who', 'discovered', 'penicillin'] ['alexander', 'fleming']
# I was wondering, "Who wrote 'Harry Potter'"? J K Rowling
# ['i', 'was', 'wondering', 'who', 'wrote', 'harry', 'potter'] ['j', 'k', 'rowling']
# "What is the national animal of Bangladesh" — do you know? Royal Bengal Tiger
# ['what', 'is', 'the', 'national', 'animal', 'of', 'bangladesh', 'do', 'you', 'know'] ['royal', 'bengal', 'tiger']
# Hey, what about this: "Which gas do plants absorb"? Carbon dioxide
# ['hey', 'what', 'about', 'this', 'which', 'gas', 'do', 'plants', 'absorb'] ['carbon', 'dioxide']
# I was wondering, "What is 'JSON' used for"? Data exchange
# ['i', 'was', 'wondering', 'what', 'is', 'json', 'used', 'for'] ['data', 'exchange']
# Can you tell me, "Who discovered 'gravity'"? Isaac Newton
# ['can', 'you', 'tell', 'me', 'who', 'discovered', 'gravity'] ['isaac', 'newton']
# I was wondering, "Who invented the 'airplane'"? Wright Brothers
# ['i', 'was', 'wondering', 'who', 'invented', 'the', 'airplane'] ['wright', 'brothers']
# Do you know, "Who invented the 'light bulb'"? Thomas Edison
# ['do', 'you', 'know', 'who', 'invented', 'the', 'light', 'bulb'] ['thomas', 'edison']
# Can you tell me, "Which gas do humans breathe"? Oxygen
# ['can', 'you', 'tell', 'me', 'which', 'gas', 'do', 'humans', 'breathe'] ['oxygen']
# Hey, what about this: "What is 'H2O' commonly called"? Water
# ['hey', 'what', 'about', 'this', 'what', 'is', 'h2o', 'commonly', 'called'] ['water']
# Quick question: "What does 'GPU' stand for"? Graphics Processing Unit
# ['quick', 'question', 'what', 'does', 'gpu', 'stand', 'for'] ['graphics', 'processing', 'unit']
# Hey, what about this: "Who discovered 'gravity'"? Isaac Newton
# ['hey', 'what', 'about', 'this', 'who', 'discovered', 'gravity'] ['isaac', 'newton']
# Can you tell me, "What is a 'URL'"? Web address
# ['can', 'you', 'tell', 'me', 'what', 'is', 'a', 'url'] ['web', 'address']
# I was wondering, "What does 'API' mean"? Application Programming Interface
# ['i', 'was', 'wondering', 'what', 'does', 'api', 'mean'] ['application', 'programming', 'interface']
# Can you tell me, "What is 'RAM'"? Computer memory
# ['can', 'you', 'tell', 'me', 'what', 'is', 'ram'] ['computer', 'memory']
# Can you tell me, "What is 'AI' short for"? Artificial Intelligence
# ['can', 'you', 'tell', 'me', 'what', 'is', 'ai', 'short', 'for'] ['artificial', 'intelligence']
# Quick question: "Who wrote 'Harry Potter'"? J K Rowling
# ['quick', 'question', 'who', 'wrote', 'harry', 'potter'] ['j', 'k', 'rowling']
# Hey, what about this: "Who discovered 'penicillin'"? Alexander Fleming
# ['hey', 'what', 'about', 'this', 'who', 'discovered', 'penicillin'] ['alexander', 'fleming']
# Do you know, "What is 'H2O' commonly called"? Water
# ['do', 'you', 'know', 'what', 'is', 'h2o', 'commonly', 'called'] ['water']
# Do you know, "What is 'ML' short for"? Machine Learning
# ['do', 'you', 'know', 'what', 'is', 'ml', 'short', 'for'] ['machine', 'learning']
# I was wondering, "What is 'NLP' short for"? Natural Language Processing
# ['i', 'was', 'wondering', 'what', 'is', 'nlp', 'short', 'for'] ['natural', 'language', 'processing']
# Do you know, "Which bird cannot fly"? Ostrich
# ['do', 'you', 'know', 'which', 'bird', 'cannot', 'fly'] ['ostrich']
# Do you know, "Which metal is liquid at room temperature"? Mercury
# ['do', 'you', 'know', 'which', 'metal', 'is', 'liquid', 'at', 'room', 'temperature'] ['mercury']
# "Which planet is known as the 'Red Planet'" — do you know? Mars
# ['which', 'planet', 'is', 'known', 'as', 'the', 'red', 'planet', 'do', 'you', 'know'] ['mars']
# Hey, what about this: "Which animal is the largest on Earth"? Blue Whale
# ['hey', 'what', 'about', 'this', 'which', 'animal', 'is', 'the', 'largest', 'on', 'earth'] ['blue', 'whale']
# "Which bird cannot fly" — do you know? Ostrich
# ['which', 'bird', 'cannot', 'fly', 'do', 'you', 'know'] ['ostrich']
# Can you tell me, "What is 'ML' short for"? Machine Learning
# ['can', 'you', 'tell', 'me', 'what', 'is', 'ml', 'short', 'for'] ['machine', 'learning']
# I was wondering, "What does 'CPU' stand for"? Central Processing Unit
# ['i', 'was', 'wondering', 'what', 'does', 'cpu', 'stand', 'for'] ['central', 'processing', 'unit']
# Do you know, "What is the main religion in Saudi Arabia"? Islam
# ['do', 'you', 'know', 'what', 'is', 'the', 'main', 'religion', 'in', 'saudi', 'arabia'] ['islam']
# Do you know, "Who wrote 'Hamlet'"? William Shakespeare
# ['do', 'you', 'know', 'who', 'wrote', 'hamlet'] ['william', 'shakespeare']
# Can you tell me, "What is 'H2O' commonly called"? Water
# ['can', 'you', 'tell', 'me', 'what', 'is', 'h2o', 'commonly', 'called'] ['water']
# I was wondering, "Who wrote 'Hamlet'"? William Shakespeare
# ['i', 'was', 'wondering', 'who', 'wrote', 'hamlet'] ['william', 'shakespeare']
# Hey, what about this: "Which planet is known as the 'Red Planet'"? Mars
# ['hey', 'what', 'about', 'this', 'which', 'planet', 'is', 'known', 'as', 'the', 'red', 'planet'] ['mars']
# "Who invented the 'light bulb'" — do you know? Thomas Edison
# ['who', 'invented', 'the', 'light', 'bulb', 'do', 'you', 'know'] ['thomas', 'edison']
# Quick question: "What is the largest ocean"? Pacific Ocean
# ['quick', 'question', 'what', 'is', 'the', 'largest', 'ocean'] ['pacific', 'ocean']
# Hey, what about this: "Who painted the 'Mona Lisa'"? Leonardo da Vinci
# ['hey', 'what', 'about', 'this', 'who', 'painted', 'the', 'mona', 'lisa'] ['leonardo', 'da', 'vinci']
# I was wondering, "What is 'ML' short for"? Machine Learning
# ['i', 'was', 'wondering', 'what', 'is', 'ml', 'short', 'for'] ['machine', 'learning']
# Hey, what about this: "What does 'HTTP' stand for"? HyperText Transfer Protocol
# ['hey', 'what', 'about', 'this', 'what', 'does', 'http', 'stand', 'for'] ['hypertext', 'transfer', 'protocol']
# Hey, what about this: "Who invented the 'telephone'"? Alexander Graham Bell
# ['hey', 'what', 'about', 'this', 'who', 'invented', 'the', 'telephone'] ['alexander', 'graham', 'bell']
# "Which country is known as the 'Land of Rising Sun'" — do you know? Japan
# ['which', 'country', 'is', 'known', 'as', 'the', 'land', 'of', 'rising', 'sun', 'do', 'you', 'know'] ['japan']
# Quick question: "Which country is known as the 'Land of Rising Sun'"? Japan
# ['quick', 'question', 'which', 'country', 'is', 'known', 'as', 'the', 'land', 'of', 'rising', 'sun'] ['japan']
# Do you know, "Who wrote 'Harry Potter'"? J K Rowling
# ['do', 'you', 'know', 'who', 'wrote', 'harry', 'potter'] ['j', 'k', 'rowling']
# Hey, what about this: "What is 'RAM'"? Computer memory
# ['hey', 'what', 'about', 'this', 'what', 'is', 'ram'] ['computer', 'memory']
# Quick question: "Who invented the 'telephone'"? Alexander Graham Bell
# ['quick', 'question', 'who', 'invented', 'the', 'telephone'] ['alexander', 'graham', 'bell']
# Quick question: "Which organ pumps blood"? Heart
# ['quick', 'question', 'which', 'organ', 'pumps', 'blood'] ['heart']
# Hey, what about this: "What does 'CPU' stand for"? Central Processing Unit
# ['hey', 'what', 'about', 'this', 'what', 'does', 'cpu', 'stand', 'for'] ['central', 'processing', 'unit']
# Can you tell me, "Which instrument measures pressure"? Barometer
# ['can', 'you', 'tell', 'me', 'which', 'instrument', 'measures', 'pressure'] ['barometer']
# I was wondering, "Which country is known as the 'Land of Rising Sun'"? Japan
# ['i', 'was', 'wondering', 'which', 'country', 'is', 'known', 'as', 'the', 'land', 'of', 'rising', 'sun'] ['japan']
# Can you tell me, "Which bird cannot fly"? Ostrich
# ['can', 'you', 'tell', 'me', 'which', 'bird', 'cannot', 'fly'] ['ostrich']
# I was wondering, "What is 'H2O' commonly called"? Water
# ['i', 'was', 'wondering', 'what', 'is', 'h2o', 'commonly', 'called'] ['water']
# I was wondering, "Which planet is known as the 'Red Planet'"? Mars
# ['i', 'was', 'wondering', 'which', 'planet', 'is', 'known', 'as', 'the', 'red', 'planet'] ['mars']
# Can you tell me, "What is the main religion in Saudi Arabia"? Islam
# ['can', 'you', 'tell', 'me', 'what', 'is', 'the', 'main', 'religion', 'in', 'saudi', 'arabia'] ['islam']
# Quick question: "Which animal is known for loyalty"? Dog
# ['quick', 'question', 'which', 'animal', 'is', 'known', 'for', 'loyalty'] ['dog']
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 166    None
# 167    None
# 168    None
# 169    None
# 170    None
# Length: 171, dtype: object

# %%
vocab
# Out:
# {'UNK': 0,
#  'what': 1,
#  'is': 2,
#  'the': 3,
#  'capital': 4,
#  'of': 5,
#  'france': 6,
#  'paris': 7,
#  'germany': 8,
#  'berlin': 9,
#  'italy': 10,
#  'rome': 11,
#  'spain': 12,
#  'madrid': 13,
#  'japan': 14,
#  'tokyo': 15,
#  'canada': 16,
#  'ottawa': 17,
#  'brazil': 18,
#  'brasilia': 19,
#  'australia': 20,
#  'canberra': 21,
#  'india': 22,
#  'new': 23,
#  'delhi': 24,
#  'china': 25,
#  'beijing': 26,
#  'russia': 27,
#  'moscow': 28,
#  'united': 29,
#  'states': 30,
#  'washington': 31,
#  'dc': 32,
#  'mexico': 33,
#  'city': 34,
#  'egypt': 35,
#  'cairo': 36,
#  'turkey': 37,
#  'ankara': 38,
#  'argentina': 39,
#  'buenos': 40,
#  'aires': 41,
#  'south': 42,
#  'korea': 43,
#  'seoul': 44,
#  'indonesia': 45,
#  'jakarta': 46,
#  'pakistan': 47,
#  'islamabad': 48,
#  'bangladesh': 49,
#  'dhaka': 50,
#  'nepal': 51,
#  'kathmandu': 52,
#  'sri': 53,
#  'lanka': 54,
#  'colombo': 55,
#  'thailand': 56,
#  'bangkok': 57,
#  'malaysia': 58,
#  'kuala': 59,
#  'lumpur': 60,
#  'vietnam': 61,
#  'hanoi': 62,
#  'uae': 63,
#  'abu': 64,
#  'dhabi': 65,
#  'iran': 66,
#  'tehran': 67,
#  'iraq': 68,
#  'baghdad': 69,
#  'saudi': 70,
#  'arabia': 71,
#  'riyadh': 72,
#  'nigeria': 73,
#  'abuja': 74,
#  'kenya': 75,
#  'nairobi': 76,
#  'chile': 77,
#  'santiago': 78,
#  'who': 79,
#  'discovered': 80,
#  'gravity': 81,
#  'isaac': 82,
#  'newton': 83,
#  'invented': 84,
#  'telephone': 85,
#  'alexander': 86,
#  'graham': 87,
#  'bell': 88,
#  'h2o': 89,
#  'commonly': 90,
#  'called': 91,
#  'water': 92,
#  'which': 93,
#  'gas': 94,
#  'do': 95,
#  'plants': 96,
#  'absorb': 97,
#  'carbon': 98,
#  'dioxide': 99,
#  'planet': 100,
#  'known': 101,
#  'as': 102,
#  'red': 103,
#  'mars': 104,
#  'painted': 105,
#  'mona': 106,
#  'lisa': 107,
#  'leonardo': 108,
#  'da': 109,
#  'vinci': 110,
#  'largest': 111,
#  'ocean': 112,
#  'pacific': 113,
#  'developed': 114,
#  'theory': 115,
#  'relativity': 116,
#  'albert': 117,
#  'einstein': 118,
#  'ai': 119,
#  'short': 120,
#  'for': 121,
#  'artificial': 122,
#  'intelligence': 123,
#  'ml': 124,
#  'machine': 125,
#  'learning': 126,
#  'nlp': 127,
#  'natural': 128,
#  'language': 129,
#  'processing': 130,
#  'does': 131,
#  'cpu': 132,
#  'stand': 133,
#  'central': 134,
#  'unit': 135,
#  'ram': 136,
#  'computer': 137,
#  'memory': 138,
#  'gpu': 139,
#  'graphics': 140,
#  'a': 141,
#  'url': 142,
#  'web': 143,
#  'address': 144,
#  'http': 145,
#  'hypertext': 146,
#  'transfer': 147,
#  'protocol': 148,
#  'json': 149,
#  'used': 150,
#  'data': 151,
#  'exchange': 152,
#  'sql': 153,
#  'database': 154,
#  'query': 155,
#  'api': 156,
#  'mean': 157,
#  'application': 158,
#  'programming': 159,
#  'interface': 160,
#  'light': 161,
#  'bulb': 162,
#  'thomas': 163,
#  'edison': 164,
#  'airplane': 165,
#  'wright': 166,
#  'brothers': 167,
#  'penicillin': 168,
#  'fleming': 169,
#  'wrote': 170,
#  'hamlet': 171,
#  'william': 172,
#  'shakespeare': 173,
#  'harry': 174,
#  'potter': 175,
#  'j': 176,
#  'k': 177,
#  'rowling': 178,
#  'country': 179,
#  'land': 180,
#  'rising': 181,
#  'sun': 182,
#  'animal': 183,
#  'king': 184,
#  'jungle': 185,
#  'lion': 186,
#  'on': 187,
#  'earth': 188,
#  'blue': 189,
#  'whale': 190,
#  'bird': 191,
#  'cannot': 192,
#  'fly': 193,
#  'ostrich': 194,
#  'loyalty': 195,
#  'dog': 196,
#  'fruit': 197,
#  'typically': 198,
#  'apple': 199,
#  'yellow': 200,
#  'banana': 201,
#  'organ': 202,
#  'pumps': 203,
#  'blood': 204,
#  'heart': 205,
#  'humans': 206,
#  'breathe': 207,
#  'oxygen': 208,
#  'metal': 209,
#  'liquid': 210,
#  'at': 211,
#  'room': 212,
#  'temperature': 213,
#  'mercury': 214,
#  'instrument': 215,
#  'measures': 216,
#  'thermometer': 217,
#  'pressure': 218,
#  'barometer': 219,
#  'main': 220,
#  'portuguese': 221,
#  'spanish': 222,
#  'religion': 223,
#  'in': 224,
#  'islam': 225,
#  'national': 226,
#  'royal': 227,
#  'bengal': 228,
#  'tiger': 229,
#  'quick': 230,
#  'question': 231,
#  'you': 232,
#  'know': 233,
#  'i': 234,
#  'was': 235,
#  'wondering': 236,
#  'hey': 237,
#  'about': 238,
#  'this': 239,
#  'can': 240,
#  'tell': 241,
#  'me': 242}

# %%
len(vocab)
# Out:
# 243

# %% [markdown]
# text to indices

# %%
def text_to_indices(text):
       indexed_text=[]
       for i in range(len(text)):
              token=text[i]
              if token in vocab:
                     indexed_text.append(vocab[token])
              else:
                     indexed_text.append(vocab['UNK'])
       return indexed_text

# %%
text_to_indices("what is the capital of Vanuatu".split())
# Out:
# [1, 2, 3, 4, 5, 0]

# %% [markdown]
# Dataset and Dataloader

# %%
! pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Using cached torch-2.11.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch) (4.15.0)
# Collecting setuptools<82 (from torch)
#   Using cached setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from torch) (2026.1.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Shuvo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from jinja2->torch) (3.0.3)
# Using cached torch-2.11.0-cp313-cp313-win_amd64.whl (114.6 MB)
# Using cached setuptools-81.0.0-py3-none-any.whl (1.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, setuptools, torch
#
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------------------------------------- 0/4 [mpmath]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    ---------- ----------------------------- 1/4 [sympy]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    -------------------- ------------------- 2/4 [setuptools]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ------------------------------ --------- 3/4 [torch]
#    ---------------------------------------- 4/4 [torch]
#
# Successfully installed mpmath-1.3.0 setuptools-81.0.0 sympy-1.14.0 torch-2.11.0
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\Shuvo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import torch
from torch.utils.data import Dataset, DataLoader

# %%
df
# Out:
#                                               question   answer
# 0                     What is the capital of "France"?    Paris
# 1                    What is the capital of "Germany"?   Berlin
# 2                      What is the capital of "Italy"?     Rome
# 3                      What is the capital of "Spain"?   Madrid
# 4                      What is the capital of "Japan"?    Tokyo
# ..                                                 ...      ...
# 166          Can you tell me, "Which bird cannot fly"?  Ostrich
# 167  I was wondering, "What is 'H2O' commonly called"?    Water
# 168  I was wondering, "Which planet is known as the...     Mars
# 169  Can you tell me, "What is the main religion in...    Islam
# 170  Quick question: "Which animal is known for loy...      Dog
#
# [171 rows x 2 columns]

# %%
df.shape[0]
# Out:
# 171

# %%
index=0 
df.iloc[index]['question']
# Out:
# 'What is the capital of "France"?'

# %%
index=0 
text_to_indices(df.iloc[index]['question'],vocab)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 index=0
# ----> 2 text_to_indices(df.iloc[index]['question'],vocab)
#
# TypeError: text_to_indices() takes 1 positional argument but 2 were given

# %%
class QADataset(Dataset):
       def __init__(self,df,vocab):
              self.df = df
              self.vocab = vocab
       def __len__(self):
              return len(self.df)
       def __getitem__(self,index):
              row = self.df.iloc[index]
              question = text_to_indices(row['question'].split())
              answer = text_to_indices(row['answer'].split())
              return torch.tensor(question), torch.tensor(answer)
