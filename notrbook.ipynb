# %%
import pandas as pd

# %%
df=pd.read_csv("gk_qna_dataset.csv")
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df=pd.read_csv("gk_qna_dataset.csv")
#       2 df.head(5)
#
# NameError: name 'pd' is not defined

# %%
df['question'][0]
# Out:
# 'What is the capital of "France"?'
